# %% [markdown]
# ## Random walk, Brownian motion
#
# 참고영상 : https://blog.naver.com/chunjein/220855745024 22:00 ~
#
# https://blog.naver.com/chunjein/220869314058

# %%
import numpy as np
import pandas as pd

def gbm(n_years=10, n_scenarios=1000, mu=0.07, sigma=0.15, steps_per_year=12, s_0=100.0):
    """
    Evolution of a Stock Price using a Geometric Brownian Motion Model
    """
    dt = 1/steps_per_year
    n_steps = int(n_years*steps_per_year)
    xi = np.random.normal(size=(n_steps, n_scenarios))
    rets = mu*dt + sigma*np.sqrt(dt)*xi
    rets = pd.DataFrame(rets)
    # to prices
    prices = s_0*(1+rets).cumprod()
    return prices

# %%
p = gbm(10, n_scenarios=3)

# %%
p.shape
# Out:
# (120, 3)

# %%
p.head()
# Out:
#             0           1           2
# 0  107.573150  103.436303  105.663415
# 1  114.318308  103.887863  106.369396
# 2  110.631714  109.160934  111.763449
# 3  122.164313  104.185550  110.582489
# 4  109.939665  102.475457  107.882270

# %%
p.plot()
# Out:
# <AxesSubplot:>

# %%
p = gbm(n_years=10, n_scenarios=1000)

# %%
def gbm0(n_years=10, n_scenarios=1000, mu=0.07, sigma=0.15, steps_per_year=12, s_0=100.0):
    """
    Evolution of a Stock Price using a Geometric Brownian Motion Model
    """
    dt = 1/steps_per_year
    n_steps = int(n_years*steps_per_year)
    xi = np.random.normal(size=(n_steps, n_scenarios))
    rets = mu*dt + sigma*np.sqrt(dt)*xi
    rets = pd.DataFrame(rets)
    # to prices
    prices = s_0*(1+rets).cumprod()
    return prices

def gbm(n_years=10, n_scenarios=1000, mu=0.07, sigma=0.15, steps_per_year=12, s_0=100.0):
    """
    Evolution of a Stock Price using a Geometric Brownian Motion Model
    """
    dt = 1/steps_per_year
    n_steps = int(n_years*steps_per_year)
    rets_plus_1 = np.random.normal(loc=(1+mu*dt), scale=(sigma*np.sqrt(dt)), size=(n_steps, n_scenarios))
    # to prices
    prices = s_0*pd.DataFrame(rets_plus_1).cumprod()
    return prices

# %%
# %timeit gbm0(n_years=5, n_scenarios=1000)
# Out:
# 2.74 ms ± 337 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit gbm1(n_years=5, n_scenarios=1000)
# Out:
# 2.24 ms ± 89.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
gbm(n_years=10, n_scenarios=20).plot(legend=False, figsize=(12,6))
# Out:
# <AxesSubplot:>

# %%
def gbm(n_years=10, n_scenarios=1000, mu=0.07, sigma=0.15, steps_per_year=12, s_0=100.0):
    """
    Evolution of a Stock Price using a Geometric Brownian Motion Model
    """
    dt = 1/steps_per_year
    n_steps = int(n_years*steps_per_year)
    rets_plus_1 = np.random.normal(loc=(1+mu*dt), scale=(sigma*np.sqrt(dt)), size=(n_steps, n_scenarios))
    rets_plus_1[0] = 1
    # to prices
    prices = s_0*pd.DataFrame(rets_plus_1).cumprod()
    return prices

# %%
gbm(n_years=10, n_scenarios=20).plot(legend=False, figsize=(12,6))
# Out:
# <AxesSubplot:>

# %%
gbm().head()
# Out:
#           0           1           2           3           4           5    \
# 0  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# 1  101.593834  113.707818   98.430724  100.361605   95.845735  110.112431
# 2   97.804269  114.713076   95.331282  106.745087  103.129438  111.206737
# 3  101.902292  115.183696   96.931007  112.900942   99.294372  110.967569
# 4  110.193400  118.433376  100.710162  108.355199   99.927805  117.099527
#
#           6           7           8           9    ...         990  \
# 0  100.000000  100.000000  100.000000  100.000000  ...  100.000000
# 1   97.189206  103.052400  105.388053  108.803219  ...   98.699189
# 2   92.660488  108.648086  101.640278  112.881065  ...   91.458475
# 3   91.509946  115.680995  101.423916  115.290211  ...  101.896033
# 4   90.866243  119.752873  102.136844  116.281928  ...  102.240077
#
#           991         992         993         994         995         996  \
# 0  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# 1  101.651498  106.695988   94.342745   98.632225   96.525579   96.374633
# 2   99.794923  109.508695   91.366375  106.100633  105.193700   97.674133
# 3  103.156801  108.580945  102.232202  109.607259  103.968775   93.462111
# 4  103.726327  110.752827  101.360825  107.913843  102.709592   90.844730
#
#           997         998         999
# 0  100.000000  100.000000  100.000000
# 1  110.229610   98.402524   98.551520
# 2  104.064069  100.318212   97.491911
# 3  101.941117   99.167643   96.506510
# 4  103.936597  106.704210  100.031567
#
# [5 rows x 1000 columns]
